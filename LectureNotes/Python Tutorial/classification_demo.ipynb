# %%
from sklearn.datasets import make_blobs
import numpy as np
import pandas as pd
# Generate a toy example using sklearn
X, y = make_blobs(n_samples=1000, centers=20, random_state=123)
labels = ["b", "r"]
y = np.take(labels, (y < 10))
print(y)

print(X.shape)
# print(y)

Y = np.expand_dims(y, axis=-1)
data = np.concatenate([X, Y], axis=-1)

data = pd.DataFrame(data, columns=['x','y', 'label'])
# Out:
# ['r' 'r' 'b' 'r' 'b' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'b' 'b' 'r' 'r' 'r' 'r'
#  'b' 'b' 'r' 'b' 'r' 'r' 'r' 'r' 'r' 'r' 'b' 'r' 'b' 'b' 'b' 'b' 'b' 'r'
#  'b' 'b' 'b' 'b' 'b' 'r' 'r' 'b' 'b' 'r' 'r' 'r' 'b' 'r' 'r' 'r' 'r' 'r'
#  'r' 'r' 'r' 'b' 'r' 'r' 'r' 'b' 'b' 'r' 'r' 'r' 'r' 'b' 'b' 'r' 'r' 'b'
#  'r' 'b' 'r' 'b' 'r' 'r' 'r' 'b' 'r' 'b' 'b' 'b' 'b' 'b' 'b' 'r' 'r' 'b'
#  'b' 'r' 'b' 'r' 'r' 'r' 'r' 'b' 'b' 'r' 'r' 'b' 'b' 'r' 'r' 'b' 'r' 'r'
#  'b' 'r' 'b' 'b' 'b' 'r' 'r' 'r' 'b' 'b' 'b' 'r' 'r' 'r' 'b' 'b' 'r' 'b'
#  'r' 'r' 'r' 'r' 'b' 'b' 'r' 'b' 'r' 'b' 'b' 'r' 'r' 'r' 'r' 'r' 'r' 'b'
#  'r' 'r' 'b' 'r' 'b' 'r' 'r' 'b' 'r' 'r' 'b' 'r' 'b' 'r' 'r' 'b' 'b' 'r'
#  'b' 'b' 'b' 'b' 'b' 'b' 'r' 'r' 'b' 'r' 'r' 'r' 'r' 'b' 'b' 'b' 'r' 'b'
#  'b' 'r' 'b' 'b' 'b' 'r' 'r' 'r' 'b' 'b' 'b' 'b' 'r' 'r' 'r' 'b' 'r' 'r'
#  'b' 'b' 'b' 'b' 'b' 'r' 'r' 'r' 'b' 'b' 'b' 'b' 'b' 'b' 'b' 'b' 'r' 'b'
#  'r' 'b' 'b' 'b' 'b' 'r' 'r' 'b' 'b' 'b' 'r' 'r' 'r' 'r' 'b' 'b' 'r' 'r'
#  'r' 'r' 'b' 'r' 'r' 'r' 'r' 'b' 'b' 'r' 'r' 'r' 'r' 'b' 'b' 'r' 'r' 'b'
#  'r' 'b' 'b' 'b' 'b' 'r' 'r' 'r' 'r' 'b' 'r' 'r' 'b' 'r' 'r' 'r' 'r' 'r'
#  'b' 'r' 'r' 'b' 'r' 'b' 'b' 'r' 'r' 'r' 'b' 'b' 'r' 'b' 'r' 'b' 'r' 'r'
#  'r' 'b' 'b' 'b' 'b' 'r' 'b' 'r' 'r' 'b' 'r' 'r' 'r' 'b' 'b' 'r' 'b' 'b'
#  'r' 'r' 'b' 'b' 'b' 'b' 'r' 'b' 'b' 'r' 'b' 'b' 'r' 'b' 'r' 'r' 'r' 'b'
#  'b' 'r' 'b' 'b' 'b' 'b' 'r' 'b' 'r' 'b' 'r' 'r' 'r' 'r' 'b' 'b' 'b' 'b'
#  'b' 'r' 'b' 'b' 'b' 'r' 'b' 'r' 'r' 'b' 'r' 'r' 'r' 'b' 'r' 'b' 'b' 'b'
#  'r' 'r' 'r' 'b' 'r' 'b' 'b' 'r' 'r' 'r' 'b' 'r' 'b' 'r' 'b' 'b' 'r' 'r'
#  'r' 'b' 'b' 'b' 'r' 'b' 'b' 'r' 'b' 'b' 'r' 'r' 'b' 'b' 'r' 'r' 'r' 'r'
#  'r' 'r' 'b' 'b' 'r' 'r' 'b' 'r' 'b' 'r' 'b' 'r' 'r' 'r' 'r' 'r' 'b' 'b'
#  'r' 'b' 'r' 'r' 'r' 'b' 'r' 'r' 'b' 'r' 'r' 'r' 'b' 'r' 'r' 'r' 'r' 'b'
#  'r' 'b' 'r' 'r' 'b' 'b' 'b' 'b' 'b' 'r' 'b' 'r' 'b' 'r' 'r' 'r' 'r' 'b'
#  'r' 'b' 'b' 'r' 'b' 'b' 'r' 'r' 'r' 'r' 'b' 'r' 'b' 'r' 'r' 'r' 'b' 'b'
#  'r' 'r' 'r' 'b' 'b' 'b' 'b' 'r' 'b' 'r' 'r' 'b' 'b' 'r' 'b' 'b' 'r' 'r'
#  'r' 'r' 'b' 'b' 'b' 'r' 'b' 'b' 'b' 'b' 'b' 'b' 'b' 'r' 'b' 'b' 'b' 'r'
#  'b' 'r' 'b' 'b' 'b' 'r' 'r' 'b' 'b' 'r' 'r' 'r' 'r' 'b' 'b' 'b' 'r' 'b'
#  'r' 'b' 'b' 'b' 'r' 'r' 'b' 'r' 'r' 'b' 'b' 'r' 'b' 'b' 'r' 'r' 'b' 'b'
#  'r' 'r' 'b' 'r' 'b' 'b' 'r' 'b' 'b' 'b' 'r' 'r' 'b' 'b' 'b' 'b' 'b' 'b'
#  'r' 'b' 'b' 'r' 'r' 'b' 'b' 'r' 'r' 'r' 'b' 'b' 'r' 'b' 'r' 'b' 'b' 'b'
#  'b' 'r' 'b' 'r' 'b' 'b' 'r' 'b' 'r' 'b' 'b' 'b' 'b' 'r' 'b' 'r' 'r' 'b'
#  'r' 'r' 'r' 'r' 'r' 'r' 'r' 'b' 'r' 'b' 'b' 'r' 'b' 'r' 'b' 'b' 'b' 'r'
#  'b' 'r' 'b' 'b' 'b' 'r' 'r' 'b' 'b' 'b' 'b' 'b' 'b' 'b' 'b' 'b' 'r' 'b'
#  'r' 'r' 'r' 'r' 'r' 'b' 'b' 'b' 'r' 'r' 'b' 'r' 'b' 'r' 'r' 'b' 'r' 'r'
#  'r' 'b' 'b' 'b' 'r' 'b' 'r' 'b' 'b' 'r' 'r' 'r' 'b' 'b' 'b' 'b' 'r' 'b'
#  'b' 'r' 'b' 'b' 'b' 'r' 'b' 'b' 'b' 'b' 'b' 'b' 'b' 'r' 'r' 'r' 'b' 'r'
#  'r' 'r' 'b' 'r' 'r' 'r' 'r' 'r' 'b' 'r' 'b' 'b' 'r' 'b' 'b' 'r' 'r' 'r'
#  'r' 'r' 'r' 'r' 'r' 'r' 'b' 'r' 'b' 'b' 'r' 'b' 'r' 'r' 'b' 'r' 'b' 'r'
#  'b' 'r' 'b' 'r' 'r' 'b' 'b' 'r' 'b' 'r' 'r' 'r' 'r' 'b' 'b' 'r' 'r' 'b'
#  'r' 'r' 'b' 'b' 'r' 'b' 'b' 'r' 'r' 'r' 'r' 'r' 'b' 'b' 'b' 'r' 'b' 'b'
#  'r' 'b' 'b' 'r' 'b' 'r' 'r' 'b' 'r' 'b' 'b' 'r' 'b' 'b' 'r' 'r' 'r' 'b'
#  'r' 'r' 'b' 'b' 'b' 'r' 'r' 'b' 'r' 'b' 'b' 'b' 'b' 'r' 'r' 'r' 'b' 'b'
#  'b' 'r' 'b' 'b' 'b' 'b' 'r' 'b' 'b' 'r' 'r' 'r' 'r' 'r' 'b' 'r' 'r' 'b'
#  'b' 'r' 'b' 'b' 'b' 'b' 'b' 'b' 'r' 'b' 'r' 'b' 'r' 'b' 'b' 'b' 'b' 'b'
#  'r' 'b' 'b' 'r' 'r' 'r' 'b' 'r' 'b' 'r' 'r' 'b' 'r' 'r' 'r' 'r' 'r' 'r'
#  'b' 'b' 'b' 'b' 'r' 'b' 'r' 'r' 'r' 'b' 'r' 'r' 'b' 'b' 'b' 'b' 'r' 'r'
#  'r' 'r' 'r' 'b' 'r' 'r' 'b' 'r' 'b' 'b' 'r' 'b' 'b' 'r' 'b' 'b' 'r' 'r'
#  'b' 'r' 'r' 'r' 'r' 'r' 'b' 'r' 'r' 'r' 'b' 'b' 'r' 'b' 'r' 'b' 'b' 'r'
#  'b' 'b' 'b' 'r' 'r' 'b' 'r' 'r' 'b' 'b' 'r' 'b' 'b' 'b' 'b' 'b' 'r' 'b'
#  'b' 'r' 'b' 'b' 'r' 'b' 'r' 'r' 'b' 'b' 'b' 'b' 'b' 'b' 'r' 'b' 'b' 'b'
#  'r' 'b' 'r' 'r' 'b' 'b' 'b' 'b' 'r' 'b' 'b' 'b' 'r' 'r' 'r' 'r' 'b' 'b'
#  'b' 'r' 'r' 'b' 'r' 'b' 'b' 'r' 'r' 'r' 'r' 'r' 'b' 'r' 'r' 'b' 'r' 'b'
#  'r' 'b' 'r' 'r' 'r' 'b' 'r' 'b' 'b' 'b' 'b' 'b' 'b' 'b' 'r' 'b' 'b' 'r'
#  'r' 'r' 'b' 'r' 'r' 'b' 'b' 'r' 'b' 'b']
# (1000, 2)

# %%
data.head(10)
# Out:
#                      x                    y label
# 0    -6.45255646603369   -8.763582588004452     r
# 1   0.2898214122160939  0.14677196152391225     r
# 2   -5.184122930268115  -1.2534702518970096     b
# 3   -4.713888470809617    3.674404625516476     r
# 4    4.515582960628491   -2.881380327190773     b
# 5  -0.5765894463501406    4.615896711742838     r
# 6   0.4202627550782958   -7.090973475638641     r
# 7    4.980083613605647  -1.4225720752999897     r
# 8    4.680253783136185  -1.2582081273528194     r
# 9    -2.16028169667958    2.751322646270088     r

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
print(labels)
for label in labels:
    print(label)
    mask = (y == label)
    print(mask)
    plt.scatter(X[mask, 0], X[mask, 1], c=label)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.show()
# Out:
# ['b', 'r']
# b
# r

# %%
from matplotlib import pyplot as plt
import numpy as np

def plot_surface(clf, X, y, 
                 xlim=(-10, 10), ylim=(-10, 10), n_steps=250, 
                 subplot=None, show=True):
    if subplot is None:
        fig = plt.figure()
    else:
        plt.subplot(*subplot)
        
    xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], n_steps), 
                         np.linspace(ylim[0], ylim[1], n_steps))
    
    if hasattr(clf, "decision_function"):
        z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
    else:
        z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
        
    z = z.reshape(xx.shape)
    plt.contourf(xx, yy, z, alpha=0.8, cmap=plt.cm.RdBu_r)
    plt.scatter(X[:, 0], X[:, 1], c=y)
    plt.xlim(*xlim)
    plt.ylim(*ylim)
    
    if show:
        plt.show()


def plot_clf(clf, X, y):
    plt.figure(figsize=(16, 8))
    plot_surface(clf, X, y, subplot=(1, 2, 1), show=False)

# %%
from sklearn.neural_network import MLPClassifier

# f(x) = nonlear(x * W + b) -> f(f(x))
# max(0, x)

clf = MLPClassifier(hidden_layer_sizes=(100, 100, 100), activation="relu", learning_rate="invscaling", verbose=True)
clf.fit(X, y)
plot_clf(clf, X, y)
# Out:
# Iteration 1, loss = 0.71436925
# Iteration 2, loss = 0.65121826
# Iteration 3, loss = 0.62500854
# Iteration 4, loss = 0.60791896
# Iteration 5, loss = 0.59465447
# Iteration 6, loss = 0.57936163
# Iteration 7, loss = 0.56553150
# Iteration 8, loss = 0.55242859
# Iteration 9, loss = 0.53996826
# Iteration 10, loss = 0.52617970
# Iteration 11, loss = 0.51328409
# Iteration 12, loss = 0.50197146
# Iteration 13, loss = 0.48918675
# Iteration 14, loss = 0.47801338
# Iteration 15, loss = 0.46829078
# Iteration 16, loss = 0.46092938
# Iteration 17, loss = 0.45294755
# Iteration 18, loss = 0.44370617
# Iteration 19, loss = 0.43593965
# Iteration 20, loss = 0.42624663
# Iteration 21, loss = 0.42477564
# Iteration 22, loss = 0.42360003
# Iteration 23, loss = 0.41426667
# Iteration 24, loss = 0.39828726
# Iteration 25, loss = 0.39208746
# Iteration 26, loss = 0.39158644
# Iteration 27, loss = 0.37837982
# Iteration 28, loss = 0.37579615
# Iteration 29, loss = 0.36447317
# Iteration 30, loss = 0.36082355
# Iteration 31, loss = 0.35612785
# Iteration 32, loss = 0.35116616
# Iteration 33, loss = 0.34973046
# Iteration 34, loss = 0.34274504
# Iteration 35, loss = 0.33570732
# Iteration 36, loss = 0.33116416
# Iteration 37, loss = 0.32467229
# Iteration 38, loss = 0.32166412
# Iteration 39, loss = 0.31851608
# Iteration 40, loss = 0.31881652
# Iteration 41, loss = 0.31578429
# Iteration 42, loss = 0.31067864
# Iteration 43, loss = 0.30495332
# Iteration 44, loss = 0.30134081
# Iteration 45, loss = 0.30406330
# Iteration 46, loss = 0.30084447
# Iteration 47, loss = 0.30066982
# Iteration 48, loss = 0.30144944
# Iteration 49, loss = 0.30301199
# Iteration 50, loss = 0.29177609
# Iteration 51, loss = 0.28760937
# Iteration 52, loss = 0.28836489
# Iteration 53, loss = 0.28811242
# Iteration 54, loss = 0.28294871
# Iteration 55, loss = 0.28425184
# Iteration 56, loss = 0.28015622
# Iteration 57, loss = 0.27962899
# Iteration 58, loss = 0.28232396
# Iteration 59, loss = 0.28194253
# Iteration 60, loss = 0.27796430
# Iteration 61, loss = 0.28157071
# Iteration 62, loss = 0.27658437
# Iteration 63, loss = 0.27187094
